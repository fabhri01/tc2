# %% [markdown]
# # TRABAJO SEMANAL 1
# > ## Alumno: Fabrizio Hermosa
# > ## Materia: Teoría de los circuitos II
# > ## Curso: R4001

# %% [markdown]
# ### *Puntos 1, 2 y 3 (Análisis de la transferencia del circuito)*
# A continuación se adjunta el pdf con el desarrollo:

# %%
from IPython.display import IFrame
IFrame("./TS1_TC2_R4001-FabrizioHermosa.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./TS1_TC2_R4001-FabrizioHermosa.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## *Punto 4 (Simulación de la función transferencia normalizada)*

# %%
# Librerías externas NumPy, SciPy y Matplotlib
from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np
import matplotlib as mpl

fig_sz_x = 13
fig_sz_y = 7
fig_dpi = 80 # dpi
fig_font_size = 16

mpl.rcParams['figure.figsize'] = (fig_sz_x, fig_sz_y)
mpl.rcParams['figure.dpi'] = fig_dpi
plt.rcParams.update({'font.size':fig_font_size})

# %%
# Librería de TC2, esta la vas a usar mucho
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot

R1 = 10
R2_arr = [5, 10, 20] #menor, igual o mayor a R1

plt.close("all")

for i in range(len(R2_arr)):
    T = TransferFunction([1, -R2_arr[i]/R1], [1, 1])

    bodePlot(T, fig_id=1, filter_description = 'R2/R1={:3.3f}'.format(R2_arr[i]))

    pzmap(T, fig_id=2, filter_description = 'R2/R1={:3.3f}'.format(R2_arr[i])) #S plane pole/zero plot

    GroupDelay(T, fig_id=3, filter_description = 'R2/R1={:3.3f}'.format(R2_arr[i]))

# %% [markdown]
# ## *Punto 5 (Simulación del circuito con los valores dados)*

# %%
from IPython.display import IFrame
IFrame("./Sim_LTspice.png", width=800, height=800)
# Out:
#         <iframe
#             width="800"
#             height="800"
#             src="./Sim_LTspice.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## *Punto 6 (¿Qué utilidad podría tener este circuito)*
# Viendo la respuesta en frecuencia se puede decir que es un pasa todo. Tiene una ganancia despreciable y la única utilidad podría ser su fase, como es de 180° en un principio serviría para invertir la fase de la señal original sin casi alterar su magnitud. Un ejemplo que se me ocurre es el de usarlo a la salida de un circuito inversor para recuperar la fase original.
