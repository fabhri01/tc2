# %% [markdown]
# <img src="../logo_UTN.svg" align="right" width="150" />
#
# #### Teoría de los Circuitos 2
#
# # Trabajo semanal 4 bis2
# #### Lugano Damian y Hermosa Fabrizio

# %% [markdown]
# ## Consigna
#
# <img src="./pics/consigna.png" align="center" width="800" />
#
# Consignas de la actividad:
#
# 👉  Obtener la plantilla de diseño pasabanda normalizada
#
# 👉  Obtener la función transferencia normalizada del prototipo pasabajo que satisfaga el requerimiento del filtro pasabanda.
#
# 👉  Obtener la transferencia pasabanda normalizada
#
# 👉  Implementar mediante secciones pasivas separadas por seguidores de tensión activos.
#
# 👉  Activar las redes pasivas mediante la red propuesta aquí debajo y comprobar mediante simulación el comportamiento deseado.
#
# <img src="./pics/GICconsigna.png" align="center" width="1000" />

# %% [markdown]
# ## Resoluciones
#
# Resolucion de Damian Lugano:

# %%
from IPython.display import IFrame
IFrame("./docs/TS4_BIS2v2.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/TS4_BIS2v2.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Resolución de Fabrizio Hermosa:

# %%
from IPython.display import IFrame
IFrame("./docs/TS4bis2_TC2_R4001-FabrizioHermosa.pdf", width=950, height=1000)
# Out:
#         <iframe
#             width="950"
#             height="1000"
#             src="./docs/TS4bis2_TC2_R4001-FabrizioHermosa.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Bibliografia utilizada para la resolución
#
# Circuito GIC pasabandas
#
# <img src="./pics/biblio1.png" align="center" width="600" />
#
# Transferencia y ecuaciones de diseño
#
# <img src="./pics/biblio2.png" align="center" width="800" />

# %% [markdown]
# ## Simulaciones
#
# ### Simulación numérica

# %%
#----------------------Imports-----------------------------------------

from scipy.signal import TransferFunction
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as ss

from pytc2.sistemas_lineales import analyze_sys, pretty_print_bicuad_omegayq, tf2sos_analog, pretty_print_SOS

from pytc2.general import print_subtitle

# %%
#----------------------Definicion de las variables---------------------

xi = 0.349
n = 3
alpha_max = 0.5

# %%
#---------------------------Definicion de H-------------------------

[z, p, k] = ss.cheb1ap(n, alpha_max)
[num, den] = ss.zpk2tf(z, p, k)
num,den = ss.lp2bp(num,den, wo=1, bw=0.2)

sos_bp = tf2sos_analog(num, den)
sos_bp[sos_bp < 1e-6] = 0.0

# %%
#-----------------------------Visualizacion----------------------------

print_subtitle('Transferencia factorizada del Filtro pasa banda Cheby de tercer orden')
pretty_print_SOS(sos_bp)
print_subtitle('Transferencia factorizada y parametrizada del Filtro pasa banda Cheby de tercer orden')
pretty_print_SOS(sos_bp, mode='omegayq')

analyze_sys(sos_bp, "Cheby")
# Out:
# #### Transferencia factorizada del Filtro pasa banda Cheby de tercer orden
# $\displaystyle   \frac{s \,\, 0.1512 }{s^2 + s \,\, 0.1253 +   1 } . \frac{s \,\, 0.1151 }{s^2 + s \,\, 0.05627 + 0.8154 } . \frac{s \,\, 0.3291 }{s^2 + s \,\, 0.06902 + 1.226 }$
# #### Transferencia factorizada y parametrizada del Filtro pasa banda Cheby de tercer orden
# $\displaystyle   \frac{s\,1.207\,\frac{  1}{7.981}}{s^2 + s \frac{  1}{7.981} +   1^2} . \frac{s\,2.045\,\frac{0.903}{16.05}}{s^2 + s \frac{0.903}{16.05} + 0.903^2} . \frac{s\,4.768\,\frac{1.107}{16.05}}{s^2 + s \frac{1.107}{16.05} + 1.107^2}$

# %% [markdown]
# ## Simulacion circuital en LTspice
#
# ### Implementacion con circuito pasivo
#
# Esquemático de pasabanda pasivo diseñado para chebyshev de tercer orden (Lugano)
#
# <img src="./pics/GICpasivo.png" align="center" width="1500" />
#
# Esquemático de pasabanda pasivo diseñado para chebyshev de tercer orden (Hermosa)
#
# <img src="./pics/GICpasivoFH.png" align="center" width="1500" />
#
# Si bien el circuito es el mismo, se observó que para distintos criterios de normalización y simulacion, los resultados son los mismos.
#
# #### Respuesta en frecuencia
#
# Solo se mostrarán los resultados de una simulación ya que ambas dieron resultados similares:
#
# Frecuencia Central $\omega_0=1$
#
# <img src="./pics/GICpasivo1.png" align="center" width="1000" />
#
# Atenuación en la banda de paso - Frecuencias de paso $\omega_1=0.905$ y $\omega_2=1.105$
#
# <img src="./pics/GICpasivo2.png" align="center" width="1000" />
#
# Atenuación en la banda de stop - Frecuencias de stop $\omega_{s1}=0.773$ y $\omega_{s2}=1.636$
#
# <img src="./pics/GICpasivo3.png" align="center" width="1000" />

# %% [markdown]
# ### Implementación activa con GIC pasabandas
#
# Circuito esquemático de GIC pasabanda diseñado para Chebyshev de tercer orden (Lugano)
#
# <img src="./pics/GICactivo.png" align="center" width="1500" />
#
# Circuito esquemático de GIC pasabanda diseñado para Chebyshev de tercer orden (Hermosa)
#
# <img src="./pics/GICactivoFH.png" align="center" width="1500" />
#
# En este caso, también se observó que para distintos criterios de simulación, los resultados fueron los mismos
#
# #### Respuesta en frecuencia
#
# Frecuencia Central $\omega_0=1$
#
# <img src="./pics/GICactivo1.png" align="center" width="1000" />
#
# Atenuación en la banda de paso - Frecuencias de paso $\omega_1=0.905$ y $\omega_2=1.105$
#
# <img src="./pics/GICactivo2.png" align="center" width="1000" />
#
# Atenuación en la banda de stop - Frecuencias de stop $\omega_{s1}=0.773$ y $\omega_{s2}=1.636$
#
# <img src="./pics/GICactivo3.png" align="center" width="1000" />

# %% [markdown]
# ## Conclusiones
#
# Como el núcleo de transformación visto en la teoría solo permite diseñar un filtro pasabanda simétrico, al principio se evaluaron otras posibilidades tales como cascadear un filtro pasa-bajo con un filtro pasa altos de manera de cumplir con la plantilla estrictamente y no atenuar de más en la banda de stop. Sin embargo, esto no puede ser posible ya que con las herramientas vistas en el curso, no se podría hacer un filtro Chebyshev que tenga una atenuación máxima en la banda de paso.
#
# Por lo tanto, se optó por diseñar un filtro pasabanda simétrico, con el núcleo de transformación conocido, de manera que cumpla con la mayor restricción del filtro. En este caso específico, la característica más exigente es la atenuación en la banda de stop, la cual es $\alpha_{min}=-16dB$ en $f_{s1}$ y $\alpha_{min}-24dB$ para la $f_{s2}$ . Por lo tanto, se eligió un orden que permita atenuar lo pedido por la plantilla para ambas frecuencias. Se observó que para orden $n=2$, se cumplía con la atenuación para la $f_{s2}$ pero no cumplía para la $f_{s1}$, por lo tanto se eligió orden $n=3$ que permite cumplir con la plantilla.
#
# Para la implementación del circuito pasivo se utilizaron 3 etapas pasabanda RLC con buffer entre ellos, sin utilizar etapas de ganancia adicional. Por otro lado para la implementación activa, se utilizó el GIC de Antoniou pasabanda, que es similar al filtro pasivo pero poniendo en derivación parte de la resistencia y activando el inductor con el GIC.
#
#
# ### Resultados obtenidos
#
# La transfrencia obtenida al diseñar el filtro fue la siguiente:
#
# \begin {equation}
#     \frac{s\,1.207\,\frac{ 1}{7.981}}{s^2 + s \frac{ 1}{7.981} + 1^2} . \frac{s\,2.045\,\frac{ 0.903}{16.05}}{s^2 + s \frac{ 0.903}{16.05} + 0.903^2}
#     . \frac{s\,4.768\,\frac{ 1.107}{16.05}}{s^2 + s \frac{ 1.107}{16.05} + 1.107^2}
# \end {equation}
# ​
# Como se puede observar, los valores de $Q_1=7.981$ y $Q_2=Q_3=16.05$ son muy elevados por lo que la factibilidad de que se puede implementar tendría que ser evaluada con un analisis de Montecarlo, de manera de determinar la sensibilidad a la variación de los valores de los componentes, teniendo en cuenta su tolerancia.
#
# Al simular el circuito pasivo, se observó que la respuesta en frecuencia es similar a la esperada pero atenuando en la banda de paso al rededor de $20dB$. Sin embargo, cumple con la atenuación máxima en la banda de paso y con la atenuación minima en la banda de stop respecto a los $-20dB$. Por lo tanto, cumpliría con la plantilla pero 20dB por debajo.
#
# Por otro lado, de la simulación del circuito activo, se observó que cumple con la plantilla teniendo una ganancia de 0dB.
#
# ### Dificultades o problemas
#
# Al momento de implementar el circuito activo con el GIC, se tuvo en cuenta de lo leído en la bibliografía(Sch. pag 184) que la ganancia máxima posible para cada etapa era de 2 veces, superando en algunos casos la ganancia necesaria. Por lo tanto, para las etapas que amplificaban más que 2 veces, se las diseñó para que sean de 0dB y se implementó una etapa de ganancia al final del filtro con un OPAMP en configuración no inversora.
#
# Por otro lado, al simular la implementación pasiva en LTspice, se observó en la respuesta en frecuencia, que la banda de paso no se correspondía a la de un Chebyshev
#
# Circuito pasivo simulado
#
# <img src="./pics/image3.png" align="center" width="1000" />
#
# Banda de paso resultante (1)
#
# <img src="./pics/image.png" align="center" width="1000" />
#
# Banda de paso resultante (2)
#
# <img src="./pics/image2.png" align="center" width="1000" />
#
# Esto se pudo resolver aumentando el valor de la resistencia, utilizada como norma de impedancia, a $1K$. Esto tiene que ver con que el programa esta hecho para simular en frecuencias más grandes y no para frecuencias y componentes normalizados por lo que las señales tienden a deformarse.

# %% [markdown]
# ## Modalidad adoptada
#
# Dada que ambos participantes no llevaban el mismo nivel de seguimiento de la materia, se resolvió que cada una de las partes haga su resolución por separado. Esto último se decidió en virtud de darle tiempo al participante que no estaban al dia para adquirir los conocimientos necesarios en función de desarrollar el trabajo. Cabe destacar que el participante que estaba al día estuvo a plena disposición del que no lo estaba en pos de brindar asistencia con la comprensión del material de estudio. A partir de esto, se fueron discutiendo los resultados parciales y despejando dudas a medida que se avanzaba con el trabajo. Por último se hizo una puesta en común, logrando un intercambio fructuoso y sobretodo el objetivo final consistente en que ambas partes estén al día y que se pueda resolver la tarea semanal al mismo nivel de entendimiento de la materia. Por último, el armado del jupyter que fue colaborativo en su totalidad.
