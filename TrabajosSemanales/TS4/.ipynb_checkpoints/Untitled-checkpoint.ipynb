# %% [markdown]
# # TRABAJO SEMANAL 4
# > ## Alumno: Fabrizio Hermosa
# > ## Materia: Teoría de los circuitos II
# > ## Curso: R4001

# %% [markdown]
# ## <u> Consignas </u>  ##

# %%
from IPython.display import IFrame
IFrame("./ConsignaTS4.png", width=900, height=600)
# Out:
#         <iframe
#             width="900"
#             height="600"
#             src="./ConsignaTS4.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## <u> Desarrollo </u>  ##
# Se adjunta un pdf con la solución de las consignas.

# %%
from IPython.display import IFrame
IFrame("./TS4_TC2_R4001-FabrizioHermosa.pdf", width=900, height=1000)

# %% [markdown]
# ## <u> BONUS </u>  ##

# %% [markdown]
# ## Simulación numérica en python ##

# %%
import numpy as np
import scipy.signal as sig
import matplotlib.pyplot as plt
#libreria de la catedra
from pytc2.sistemas_lineales import pzmap, GroupDelay, bodePlot, analyze_sys, pretty_print_SOS, tf2sos_analog
from pytc2.general import print_subtitle

## Filtro pasabajos prototipo

#Plantilla
#wp = 1
ws = 4
alpha_max = 1
alpha_min = 30

#Desarollo
eps = np.sqrt(10**(alpha_max/10) - 1)
orden = np.ceil(0.5*(np.log10((10**(alpha_min*0.1) - 1)/ eps**2) / np.log10(ws)))
z, p, k = sig.buttap(orden) #polos y ceros de un Butterworth de este orden
num, den = sig.zpk2tf(z,p,k) #numerador y denominador de la transferencia
print_subtitle("Transferencia normalizada filtro pasabajos Butterworth prototipo")
sos_lp = tf2sos_analog(num, den) #factorizo en sistemas de segundo orden
sos_lp[sos_lp < 1e-6] = 0.0
pretty_print_SOS(sos_lp)

analyze_sys(sos_lp)
# Out:
# #### Transferencia normalizada filtro pasabajos Butterworth prototipo
# $\displaystyle   \frac{1.154 }{s +   1 } . \frac{0.8663 }{s^2 + s \,\,   1 +   1 }$

# %%
## Filtro pasa altos objetivo
num, den = sig.lp2lp(num, den, eps**(-1/orden)) #desnormalizo el filtro pasa bajos por usar wbutter, obtengo MP
num, den = sig.lp2hp(num, den) #transformo el filtro pasabajos de MP desnormalizado a un filtro pasa altos
sos_hp = tf2sos_analog(num, den) #factorizo en sistemas de segundo orden
print_subtitle("Transferencia filtro pasa altos de Máxima Planicidad")
pretty_print_SOS(sos_hp)
analyze_sys(sos_hp)
# Out:
# #### Transferencia filtro pasa altos de Máxima Planicidad
# $\displaystyle   \frac{s \,\, 1.154 }{s + 0.7984 } . \frac{s^2 \,\, 0.8662 }{s^2 + s \,\, 0.7984 + 0.6374 }$

# %% [markdown]
# ## Simulación circuital en LTspice ##

# %% [markdown]
# Circuito normalizado con estructuras pasivas RC y RLC.
#
# Se puede ver en la ventana de mediciones que para 1Hz ($f_p$ normalizada) atenúa ~1dB, mientras que para 250mHz (fs normalizada, $f_s' = \frac{fs}{fp} = 0.25 = 250m)$ atenúa ~30dB, cumpliendo con la consigna.

# %%
IFrame("./Sim_LTspice3.png", width=900, height=700)
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="./Sim_LTspice3.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Circuito desnormalizado con el inductor activado mediante el GIC de Antoniou.
#
# Se pueden ver pequeñas variaciones en las mediciones con respecto a la atenuación, sin embargo, cumple con la plantilla propuesta. Se cree que puede ser por los opamps utilizados, ya que no serían tan ideales.

# %%
IFrame("./Sim_LTspice4.png", width=900, height=700)
# Out:
#         <iframe
#             width="900"
#             height="700"
#             src="./Sim_LTspice4.png"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ## <u> Conclusiones </u> ##
